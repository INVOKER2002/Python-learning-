# %%
import pandas as pd

# %%
#air bnb dataset cleaning 
df = pd.read_csv("Airbnb_Open_Data.csv")
# Out:
# C:\Users\boyas\AppData\Local\Temp\ipykernel_33556\3851648005.py:2: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Airbnb_Open_Data.csv")

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license','id']

# %%
len(columns_to_keep), len(columns_to_drop)
# Out:
# (19, 7)

# %% [markdown]
# filtering data

# %%
df = df[columns_to_keep]
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.shape
# Out:
# (102599, 19)

# %% [markdown]
# RENAMING THE COLOUMNS

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.rename(columns={'NAME':'Name',}, inplace=True)
# Out:
# C:\Users\boyas\AppData\Local\Temp\ipykernel_33556\1959567024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'NAME':'Name',}, inplace=True)

# %%
df
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
for i in df.columns:
    print(i.upper())
# Out:
# NAME
# HOST ID
# HOST_IDENTITY_VERIFIED
# HOST NAME
# NEIGHBOURHOOD GROUP
# NEIGHBOURHOOD
# LAT
# LONG
# COUNTRY
# COUNTRY CODE
# INSTANT_BOOKABLE
# CANCELLATION_POLICY
# ROOM TYPE
# CONSTRUCTION YEAR
# PRICE
# SERVICE FEE
# MINIMUM NIGHTS
# NUMBER OF REVIEWS
# LAST REVIEW

# %%
df.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
newcolumns = []
for i in df.columns:
    newcolumns.append(i.upper())

# %%
df.columns = newcolumns

# %%
df.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %%
newcolumns
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %% [markdown]
# Deleting duplicate data and dropping it

# %%
df.duplicated().sum()
# Out:
# np.int64(541)

# %%
df.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\boyas\AppData\Local\Temp\ipykernel_33556\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    102058
# Name: count, dtype: int64

# %%
df.duplicated(subset='NAME').sum()
# Out:
# np.int64(40776)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# NAME                        250
# HOST ID                       0
# HOST_IDENTITY_VERIFIED      289
# HOST NAME                   404
# NEIGHBOURHOOD GROUP          29
# NEIGHBOURHOOD                16
# LAT                           8
# LONG                          8
# COUNTRY                     532
# COUNTRY CODE                131
# INSTANT_BOOKABLE            105
# CANCELLATION_POLICY          76
# ROOM TYPE                     0
# CONSTRUCTION YEAR           214
# PRICE                       247
# SERVICE FEE                 273
# MINIMUM NIGHTS              400
# NUMBER OF REVIEWS           183
# LAST REVIEW               15832
# dtype: int64

# %%
df.isna().value_counts()
# Out:
# NAME   HOST ID  HOST_IDENTITY_VERIFIED  HOST NAME  NEIGHBOURHOOD GROUP  NEIGHBOURHOOD  LAT    LONG   COUNTRY  COUNTRY CODE  INSTANT_BOOKABLE  CANCELLATION_POLICY  ROOM TYPE  CONSTRUCTION YEAR  PRICE  SERVICE FEE  MINIMUM NIGHTS  NUMBER OF REVIEWS  LAST REVIEW
# False  False    False                   False      False                False          False  False  False    False         False             False                False      False              False  False        False           False              False          83969
#                                                                                                                                                                                                                                                         True           15373
# ...

# %%
df.drop(columns=['LAST REVIEW'], inplace=True) # drop the unnamed column
# Out:
# C:\Users\boyas\AppData\Local\Temp\ipykernel_33556\1706338097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['LAST REVIEW'], inplace=True) # drop the unnamed column

# %%
df.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS'],
#       dtype='object')

# %%
df.dropna(inplace=True) # drop all rows with any NaN values
# Out:
# C:\Users\boyas\AppData\Local\Temp\ipykernel_33556\4134702392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True) # drop all rows with any NaN values

# %%
df.isna().sum()
# Out:
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# dtype: int64

# %%
df["HOST_IDENTITY_VERIFIED"].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: HOST_IDENTITY_VERIFIED, Length: 99342, dtype: object

# %%
df
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 unconfirmed   Madaline            Brooklyn
# ...

# %%
df.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS'],
#       dtype='object')

# %%
df['INSTANT_BOOKABLE'].apply(lambda x : 1 if x==True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: INSTANT_BOOKABLE, Length: 99342, dtype: int64

# %%
df.shape
# Out:
# (99342, 18)

# %%
type(df['INSTANT_BOOKABLE'][5])
# Out:
# bool

# %%
df.reset_index(inplace=True)

# %%
type(df['INSTANT_BOOKABLE'][15])
# Out:
# bool

# %%
df['PRICE'].sample(5)
# Out:
# 29562      $179
# 83439      $388
# 39468    $1,117
# 13873      $169
# 46931      $770
# Name: PRICE, dtype: object

# %%
df['PRICE']=df['PRICE'].str.replace("$","")
# Out:
# C:\Users\boyas\AppData\Local\Temp\ipykernel_33556\4172201083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PRICE']=df['PRICE'].str.replace("$","")

# %%
df['PRICE']=df['PRICE'].str.replace(",","")
# Out:
# C:\Users\boyas\AppData\Local\Temp\ipykernel_33556\2897458497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PRICE']=df['PRICE'].str.replace(",","")

# %%
df['PRICE'].astype(int)
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: PRICE, Length: 99342, dtype: int64

# %%
df.to_csv("Airbnb_Open_Data_Cleaned.csv", index=False) # save the cleaned data to a new csv file

# %%
data=pd.read_csv("Airbnb_Open_Data_Cleaned.csv")

# %%
data.head()
# Out:
#    index                                              NAME      HOST ID  \
# 0      0                Clean & quiet apt home by the park  80014485718
# 1      1                             Skylit Midtown Castle  52335172823
# 2      4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3      5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4      7                                   BlissArtsSpace!  90821839709
#
#   HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP       NEIGHBOURHOOD  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 2               verified    Lyndon           Manhattan         East Harlem
# 3               verified  Michelle           Manhattan         Murray Hill
# 4            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         LAT      LONG        COUNTRY COUNTRY CODE  INSTANT_BOOKABLE  \
# ...

# %%
data.drop(columns=['index'],inplace=True)

# %%
data.sample(10)
# Out:
#                                                     NAME      HOST ID  \
# 69154                1B in NYC - East Village, Manhattan  63294252193
# 41434                                    Brenda's Palace  24724572684
# 63555  LOVELY 1 BED ROOM 10 MIN FR JFK WITH PRIVATE P...  93601035572
# 87674                 Private room in Flatbush Brooklyn!  29236670433
# 84017                        Pure Luxury in Top Location  38059637009
# 32299     NY HILTON CLUB 2 BR SUITE Luxury Holidays 2019  68028068033
# 40403           Stylish Private Bedroom in Ridgewood, NY  69729300793
# 37118  *NO GUEST SERVICE FEE* Beekman Tower Studio Su...  80207245257
# 16278                          Sunny 1BR in East Village  18100324600
# 63903                                    Canarsie Plaza.  65416344465
#
#       HOST_IDENTITY_VERIFIED   HOST NAME NEIGHBOURHOOD GROUP  \
# 69154            unconfirmed        Gwen           Manhattan
# 41434            unconfirmed      Brenda            Brooklyn
# ...
