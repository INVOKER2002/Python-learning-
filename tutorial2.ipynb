# %%
import pandas as pd
#simple import to import the pandas library

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A','B','C'])
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.head(2)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df.tail(2)
# Out:
#    A  B  C
# 1  4  5  6
# 2  7  8  9

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
coffee = pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('./data/results.parquet')
bios = pd.read_csv('./data/bios.csv')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail(7)
# Out:
#          Day Coffee Type  Units Sold
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(6)
# Out:
#          Day Coffee Type  Units Sold
# 13    Sunday       Latte          35
# 3    Tuesday       Latte          20
# 6   Thursday    Espresso          40
# 9     Friday       Latte          35
# 12    Sunday    Espresso          45
# 0     Monday    Espresso          25

# %%
#.loc[#rows,#coloumns]
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[(bios['height_cm']>215)& (bios['born_country']=='USA'),["name","height_cm"]]
# Out:
#                     name  height_cm
# 5781      Tommy Burleson      223.0
# 6722    Shaquille O'Neal      216.0
# 6937      David Robinson      216.0
# 123850    Tyson Chandler      216.0

# %%
bios[bios['name'].str.contains("S")]
# Out:
#         athlete_id                    name   born_date   born_city  \
# 32              33        Stéphane Renault  1968-03-01    Barfleur
# 33              34  Jean-Pierre Samazeuilh  1891-01-17    Bordeaux
# 34              35         Fabrice Santoro  1972-12-09      Tahiti
# 46              47   Gladys Eastlake-Smith  1883-08-14    Lewisham
# 47              48              Sara Gomer  1964-05-13     Torquay
# ...            ...                     ...         ...         ...
# 145469      149196  Danyal Saveh Shemshaki  1997-07-02      Tehran
# 145472      149199        Tobias Schneider  1992-07-02        Roth
# 145488      149215            Shakeel John  2001-07-30  Mount Hope
# 145490      149217             Sin Ye-Chan  1995-06-13         NaN
# 145497      149224         Yuliya Smirnova  1998-05-08      Kotlas
#
#             born_region born_country                       NOC  height_cm  \
# 32               Manche          FRA                    France      180.0
# ...

# %%
bios[bios['name'].str.startswith("S")]
# Out:
#         athlete_id               name   born_date        born_city  \
# 32              33   Stéphane Renault  1968-03-01         Barfleur
# 47              48         Sara Gomer  1964-05-13          Torquay
# 65              66        Sara Sankey  1967-09-29        Southport
# 68              69          Sam Smith  1971-11-27           Epping
# 73              74         Sky Andrew  1962-03-31           Newham
# ...            ...                ...         ...              ...
# 145431      149154    Sean FitzSimons  2000-09-22       Hood River
# 145456      149182    Sophie Sorschag  1998-11-14          Villach
# 145465      149192  Stanislav Galiyev  1992-01-17  Moskva (Moscow)
# 145488      149215       Shakeel John  2001-07-30       Mount Hope
# 145490      149217        Sin Ye-Chan  1995-06-13              NaN
#
#             born_region born_country                  NOC  height_cm  \
# 32               Manche          FRA               France      180.0
# ...
